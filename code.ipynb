# %% [markdown]
# trabajo práctico N° 2
#
# 3) Utilice el comando pip install matplotplib para instalar dicho paquete, al ejecutarlo se abrio la siguiente imagen
#
# ![2022-04-23%20%281%29.png](attachment:2022-04-23%20%281%29.png)
#
#
# 4) al ejecutar los demas archivos se abrieron los siguientes graficos:
# !
#
#
# 5) al eliminar la libreria Matplotlib (con el comando pip uninstall Matplotlib) cuando quiero ejecutar el archivo line.py el mismo no se puede abrir sin tener dicha libreria
#
# 6) con el comando pip install pandas instale la libreria antes mencionada, donde al ejecutar el archivo code/data/pand.py el mismo se cerraba. Por lo que agregue al codigo la siguiente linea:  import msvcrt, msvcrt.getch()
#
# 7) al agregar la linea df.decribe() al acrhivo pand.py e imprimirlo me mostro el los siguientes resultados:
#
# 8) los resultados que devuelven al añadir df.head y df.tail en las lineas son los siguientes:
